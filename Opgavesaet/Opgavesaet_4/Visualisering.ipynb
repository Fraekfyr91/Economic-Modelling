# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#del 1
df1 = pd.read_excel ('solve_model1.xlsx',index_col = 0, sheet_name='ARK_navn')
df2 = pd.read_excel ('solve_model1.xlsx', index_col = 0, sheet_name='ARK_navn2')
#del 2
df3 = pd.read_excel ('solve_model2.xlsx', index_col = 0, sheet_name='ARK_navn')
df4 = pd.read_excel ('solve_model2.xlsx',index_col = 0, sheet_name='ARK_navn2')
#del 3
df5 = pd.read_excel ('solve_model3.xlsx', index_col = 0, sheet_name='ARK_navn')
df6 = pd.read_excel ('solve_model3.xlsx', index_col = 0, sheet_name='ARK_navn2')

# %% [markdown]
# # Opgave 1

# %%
# calculate relative change
rel1 = (df2/df1-1)*100
# plot 0 baseline
plt.axhline(y=0, color='black', linestyle=':')
# plot series
plt.plot(rel1.I, color = 'lightgray', label= 'shock 1, I 20% stigning t=9')
plt.plot(rel1.K, color = 'darkgray', label= 'shock 1, K')

# plot Convergens line
plt.axhline(y=max(rel1.I), color='darkslategray', linestyle=':')
#plot Convergens text
plt.text(25,max(rel1.I)-2, f'Konvergens til: {round(max(rel1.I))} % stigning')
#plot ticks
plt.xticks(ticks= rel1.index[0::5])
#plot legend
plt.legend()
#rotate ticks
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Opgave 2

# %%
rel2 = (df4/df3-1)*100
rel2.plot()
# Out:
# <AxesSubplot:>

# %%
# calculate relative change
rel2 = (df4/df3-1)*100
# plot 0 baseline
plt.axhline(y=0, color='black', linestyle=':')
# plot series
plt.plot(rel2.y, color = 'lightgray', label= 'shock 1, y, s 5% stigning t=10')
plt.plot(rel2.k, color = 'darkgray', label= 'shock 1, k')
plt.plot(rel2.c,  label= 'shock 1, c')
plt.plot(rel2.i,  label= 'shock 1, i')
# plot Convergens line
#plt.axhline(y=max(rel2.y), color='darkslategray', linestyle=':')
#plot Convergens text
#plt.text(25,max(rel2.y)-2, f'Konvergens til: {round(max(rel2.y))} % stigning')
#plot ticks
plt.xticks(ticks= rel2.index[0::5])
#plot legend
plt.legend()
#rotate ticks
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Opgave 3

# %%
df5.columns
# Out:
# Index(['C', 'r', 'B', 'Y'], dtype='object')

# %%
# calculate relative change
rel3 = (df6/df5-1)*100
# plot 0 baseline
plt.axhline(y=0, color='black', linestyle=':')
# plot series
plt.plot(rel3.Y, color = 'lightgray', label= 'shock 1, Y 5% stigning t=20')
plt.plot(rel3.C, color = 'darkgray', label= 'shock 1, C')
plt.plot(rel3.r,  label= 'shock 1, r')
#plt.plot(rel3.B,  label= 'shock 1, i')
# plot Convergens line
#plt.axhline(y=max(rel2.y), color='darkslategray', linestyle=':')
#plot Convergens text
#plt.text(25,max(rel2.y)-2, f'Konvergens til: {round(max(rel2.y))} % stigning')
#plot ticks
plt.xticks(ticks= rel3.index[0::5])
#plot legend
plt.legend()
#rotate ticks
plt.xticks(rotation=45)
plt.show()

# %%
# plot 0 baseline
plt.axhline(y=0, color='black', linestyle=':')
# plot series
#plt.plot(rel3.Y, color = 'lightgray', label= 'shock 1, Y 5% stigning t=20')
#plt.plot(rel3.C, color = 'darkgray', label= 'shock 1, C')
#plt.plot(rel3.r,  label= 'shock 1, r')
plt.plot(rel3.B,  label= 'shock 1, B')
# plot Convergens line
plt.axhline(y=max(rel3.B), color='darkslategray', linestyle=':')
#plot Convergens text
plt.text(25,min(rel3.B)+2, f'Konvergens til: {round(min(rel3.B))} % fald')
#plot ticks
plt.xticks(ticks= rel3.index[0::5])
#plot legend
plt.legend()
#rotate ticks
plt.xticks(rotation=45)
plt.show()
