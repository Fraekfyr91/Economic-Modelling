# %%
import plotly.express as px
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#del 1a
df1 = pd.read_excel ('solve_model1a.xlsx',index_col = 0, sheet_name='ARK_navn')
df2 = pd.read_excel ('solve_model1a.xlsx',index_col = 0, sheet_name='ARK_navn2')
df3 = pd.read_excel ('solve_model1a.xlsx', index_col = 0, sheet_name='ARK_navn3')
#del 1b
df4 = pd.read_excel ('solve_model1b.xlsx', index_col = 0, sheet_name='ARK_navn')
df5 = pd.read_excel ('solve_model1b.xlsx',index_col = 0, sheet_name='ARK_navn2')
df6 = pd.read_excel ('solve_model1b.xlsx',index_col = 0, sheet_name='ARK_navn3')
#del 1c
df7 = pd.read_excel ('solve_model1c.xlsx', index_col = 0, sheet_name='ARK_navn')
df8 = pd.read_excel ('solve_model1c.xlsx', index_col = 0, sheet_name='ARK_navn2')
df9 = pd.read_excel ('solve_model1c.xlsx', index_col = 0, sheet_name='ARK_navn3')
#del 2a
df10 = pd.read_excel ('solve_model2.xlsx',index_col = 0, sheet_name='ARK_navn')
df11 = pd.read_excel ('solve_model2.xlsx', index_col = 0, sheet_name='ARK_navn2')
df12 = pd.read_excel ('solve_model2.xlsx', index_col = 0, sheet_name='ARK_navn3')
df13 = pd.read_excel ('solve_model2.xlsx',index_col = 0, sheet_name='ARK_navn4')

df14 = pd.read_excel ('solve_model2.xlsx', index_col = 0, sheet_name='ARK_navn5')
df15 = pd.read_excel ('solve_model2.xlsx', index_col = 0, sheet_name='ARK_navn6')
df16 = pd.read_excel ('solve_model2.xlsx', index_col = 0, sheet_name='ARK_navn7')

# %%
def rel_df(df):
    df1 = pd.DataFrame()
    for i in range(1,len(df.columns)):

        col = (df.iloc[:,i]/df.iloc[:,0]-1)*100
        df1.loc[:,'shock'+str(i)] = col
    return df1
def rel_bar_plot(name, change, title, water):

    # Figure Size
    fig, ax = plt.subplots(figsize =(16, 9))

    # Horizontal Bar Plot
    ax.barh(name, change)

    # Remove axes splines
    for s in ['top', 'bottom', 'left', 'right']:
        ax.spines[s].set_visible(False)

    # Remove x, y Ticks
    ax.xaxis.set_ticks_position('none')
    ax.yaxis.set_ticks_position('none')

    # Add padding between axes and labels
    ax.xaxis.set_tick_params(pad = 5)
    ax.yaxis.set_tick_params(pad = 10)

    # Add x, y gridlines
    ax.grid(b = True, color ='grey',
            linestyle ='-.', linewidth = 0.5,
            alpha = 0.2)

    # Show top values
    ax.invert_yaxis()

    # Add annotation to bars
    for i in ax.patches:
        plt.text(i.get_width()+0.2, i.get_y()+0.5,
                 str(round((i.get_width()), 2)),
                 fontsize = 10, fontweight ='bold',
                 color ='grey')

    # Add Plot Title
    ax.set_title(title,
                 loc ='left', )

    # Add Text watermark
    fig.text(0.9, 0.15, water, fontsize = 12,
             color ='grey', ha ='right', va ='bottom',
             alpha = 0.7)

    # Show Plot
    plt.show()
    
def ser_plot(df):
    # plot 0 baseline
    plt.axhline(y=0, color='black', linestyle=':')
    # plot series
    cols = df.columns
    
    plt.plot(df, label= cols)

    #plot ticks
    plt.xticks(ticks= df.index[0::5])
    #plot legend
    plt.legend()
    #rotate ticks
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# # Del 1a

# %%
res1 = pd.concat([df1, df2], axis=1,  ignore_index=True)
rel1 = rel_df(res1)
rel_bar_plot(rel1['shock1'].index, rel1['shock1'],
             'Shock 1 relative ændringer', 'Hjemmeopgave 2a')
ser_plot(df3)

# %% [markdown]
# # Del 1b

# %%
res2 = pd.concat([df4, df5], axis=1,  ignore_index=True)
rel2 = rel_df(res2)
rel_bar_plot(rel2['shock1'].index, rel2['shock1'],
             'Shock 1 relative ændringer', 'Hjemmeopgave 2b')
ser_plot(df6)

# %% [markdown]
# # Del 1.c

# %%
res3 = pd.concat([df7, df8], axis=1,  ignore_index=True)
rel3 = rel_df(res3)
rel_bar_plot(rel3['shock1'].index, rel3['shock1'],
             'Shock 1 relative ændringer', 'Hjemmeopgave 2c')
ser_plot(df9)

# %% [markdown]
# # del 2

# %%
res4 = pd.concat([df10, df11], axis=1,  ignore_index=True)
rel4 = rel_df(res4)
rel_bar_plot(rel4['shock1'].index, rel4['shock1'],
             'Shock 1 relative ændringer', 'Hjemmeopgave 2')
ser_plot(df14)
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
res5 = pd.concat([df10, df12], axis=1,  ignore_index=True)
rel5 = rel_df(res5)
rel_bar_plot(rel5['shock1'].index, rel5['shock1'],
             'Shock 2 relative ændringer', 'Hjemmeopgave 2')
ser_plot(df15[['EV','EVG']])
# Out:
# posx and posy should be finite values
# posx and posy should be finite values

# %%
df16
# Out:
#          EVI       EVP        EVG         EV
# 0   9.753533 -8.760917        NaN   0.992616
# 1   9.753533 -8.760917  -0.091377   0.901239
# 2   9.753533 -8.760917  -0.192896   0.799721
# 3   9.753533 -8.760917  -0.306342   0.686275
# 4   9.753533 -8.760917  -0.433949   0.558667
# 5   9.753533 -8.760917  -0.578546   0.414070
# 6   9.753533 -8.760917  -0.743767   0.248849
# 7   9.753533 -8.760917  -0.934365   0.058252
# 8   9.753533 -8.760917  -1.156670  -0.164054
# 9   9.753533 -8.760917  -1.419314  -0.426698
# 10  9.753533 -8.760917  -1.734372  -0.741756
# 11  9.753533 -8.760917  -2.119273  -1.126656
# 12  9.753533 -8.760917  -2.600135  -1.607519
# 13  9.753533 -8.760917  -3.217957  -2.225341
# 14  9.753533 -8.760917  -4.040969  -3.048353
# 15  9.753533 -8.760917  -5.191745  -4.199128
# 16  9.753533 -8.760917  -6.914762  -5.922146
# 17  9.753533 -8.760917  -9.778087  -8.785471
# 18  9.753533 -8.760917 -15.473486 -14.480869
# 19  9.753533 -8.760917 -32.312388 -31.319772

# %%
res6 = pd.concat([df10, df13], axis=1,  ignore_index=True)
rel6 = rel_df(res6)
rel_bar_plot(rel6['shock1'].index, rel6['shock1'],
             'Shock 3 relative ændringer', 'Hjemmeopgave 2')
ser_plot(df16[['EV','EVG']])
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
